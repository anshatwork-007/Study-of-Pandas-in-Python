# %% [markdown]
# <a href="https://colab.research.google.com/github/anshatwork-007/Study-of-Pandas-in-Python/blob/main/Experiment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Ansh Yadav
# # Branch: ENTC
# # Batch: 2025-29
# # Experiment 9
#
# ## Title: Study of Pandas in Python

# %%
import pandas as pd
s = pd.Series([1, 3, 5, 6, 8])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
# Create DataFrame

data = {"Name":["A","B","C"],
        "Marks":[85,90,95]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     95

# %%
# Find structure of DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.size
# Out:
# 6

# %%
df.ndim
# Out:
# 2

# %%
# Display Column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
## Access individual colums
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    95
# Name: Marks, dtype: int64

# %%
# Access Specicfic row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
# Add a new column

df["Grade"] = ["First Class", "Distinction", "Second Class"]

# %%
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     95  Second Class

# %%
# Update data in dataframe
# Change marks of A to 88
df.loc[0,"Marks"] = 88

# %%
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     95

# %%
# Delete a column
df.drop("Grade", axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     95

# %%
# Perform basic Statistical Analysis
min1 = df["Marks"].min()
min1
# Out:
# 88

# %%
max1 = df["Marks"].max()
max1
# Out:
# 95

# %%
mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(91.0)

# %%
# Apply condition(Filtering)
# Diplay students scoring more than 80

df[df["Marks"] > 80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     95
